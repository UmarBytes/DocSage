# %% [markdown]
# ## Ignore Warnings:
# This cell disables warnings to maintain a clean output during execution.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import Required Libraries:
# This cell imports the necessary libraries for Grad-CAM

# %%
import os
import cv2
import numpy as np
import timm
import torch
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

# %% [markdown]
# ## Set Device:
# This cell checks for GPU availability and sets the device to either cuda or cpu.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## Define Custom Dataset:
# This cell defines a class for creating a custom dataset for image loading and processing.

# %%
class CustomImageDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        for class_dir in os.listdir(root_dir):
            class_path = os.path.join(root_dir, class_dir)
            if os.path.isdir(class_path):
                for img_file in os.listdir(class_path):
                    self.image_paths.append((os.path.join(class_path, img_file), class_dir))

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path, label = self.image_paths[idx]
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform:
            image = self.transform(image)
        return image, img_path

# %% [markdown]
# ## Apply Transformations:
# This cell sets up transformations for test data preprocessing.

# %%
test_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %% [markdown]
# ## Load The Dataset:
# Loading the images from the test dataset

# %%
test_dir = r"C:\Users\jamee\Favorites\Downloads\GradCam"
test_dataset = CustomImageDataset(test_dir, transform=test_transforms)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
print(f"Loaded {len(test_dataset)} test images.")
# Out:
# Loaded 512 test images.

# %% [markdown]
# ## Load Swin Transformer model:

# %%
num_classes = len(os.listdir(test_dir))
model = timm.create_model('swin_base_patch4_window7_224', pretrained=False, num_classes=num_classes)
model.load_state_dict(torch.load("swin_skin_disease_model_with3.pth", map_location=device))
model = model.to(device)
model.eval()
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# # Define the reshape transform for Swin Transformer compatibility

# %%
def reshape_transform(tensor):
    if len(tensor.shape) == 3:  # Handle Swin Transformer activations
        batch_size, num_patches, num_channels = tensor.shape
        height = width = int(num_patches ** 0.5)  # Assuming square patches
        tensor = tensor.permute(0, 2, 1).contiguous()  # (B, C, Patches)
        tensor = tensor.view(batch_size, num_channels, height, width)  # Reshape to (B, C, H, W)
    return tensor

# %% [markdown]
# ## Initialize Model:
# This cell loads a pre-trained model and prepares it for Grad-CAM visualization.

# %%
target_layers = [model.layers[-1].blocks[-1].attn]  # Experiment with `attn` layer for better results
cam = GradCAM(model=model, target_layers=target_layers, reshape_transform=reshape_transform)

# Output directory for visualizations
output_dir = os.path.join(test_dir, "grad_cam_visualizations")
os.makedirs(output_dir, exist_ok=True)
print("Grad-CAM initialized successfully!")
# Out:
# Grad-CAM initialized successfully!

# %% [markdown]
# ## Save Results:
# This cell saves the Grad-CAM results as output images in a specified directory.
# ## Evaluate Model Performance:
# This cell evaluates the model’s performance using the provided dataset and metrics.

# %%
for i, (image_tensor, img_path) in enumerate(test_loader):
    image_tensor = image_tensor.to(device)
    img_path = img_path[0]  # Extract single image path

    # Generate Grad-CAM heatmap
    targets = [ClassifierOutputTarget(0)]  # Replace 0 with your desired class index if needed
    grayscale_cam = cam(input_tensor=image_tensor, targets=targets)[0]  # [0] for single image

    # Normalize the grayscale CAM to remove noise
    grayscale_cam = (grayscale_cam - grayscale_cam.min()) / (grayscale_cam.max() - grayscale_cam.min())

    # Load the original image for visualization
    original_image = cv2.imread(img_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
    original_image = cv2.resize(original_image, (224, 224))
    original_image = np.float32(original_image) / 255.0

    # Overlay Grad-CAM heatmap on the original image
    heatmap = show_cam_on_image(original_image, grayscale_cam, use_rgb=True)

    # Save the visualization
    output_path = os.path.join(output_dir, f"grad_cam_{i + 1}.jpg")
    cv2.imwrite(output_path, cv2.cvtColor(heatmap, cv2.COLOR_RGB2BGR))
    print(f"Saved Grad-CAM visualization for image {i + 1} at {output_path}.")
# Out:
# Saved Grad-CAM visualization for image 1 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_1.jpg.
# Saved Grad-CAM visualization for image 2 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_2.jpg.
# Saved Grad-CAM visualization for image 3 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_3.jpg.
# Saved Grad-CAM visualization for image 4 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_4.jpg.
# Saved Grad-CAM visualization for image 5 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_5.jpg.
# Saved Grad-CAM visualization for image 6 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_6.jpg.
# Saved Grad-CAM visualization for image 7 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_7.jpg.
# Saved Grad-CAM visualization for image 8 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_8.jpg.
# Saved Grad-CAM visualization for image 9 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_9.jpg.
# Saved Grad-CAM visualization for image 10 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_10.jpg.
# Saved Grad-CAM visualization for image 11 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_11.jpg.
# Saved Grad-CAM visualization for image 12 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_12.jpg.
# Saved Grad-CAM visualization for image 13 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_13.jpg.
# Saved Grad-CAM visualization for image 14 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_14.jpg.
# Saved Grad-CAM visualization for image 15 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_15.jpg.
# Saved Grad-CAM visualization for image 16 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_16.jpg.
# Saved Grad-CAM visualization for image 17 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_17.jpg.
# Saved Grad-CAM visualization for image 18 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_18.jpg.
# Saved Grad-CAM visualization for image 19 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_19.jpg.
# Saved Grad-CAM visualization for image 20 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_20.jpg.
# Saved Grad-CAM visualization for image 21 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_21.jpg.
# Saved Grad-CAM visualization for image 22 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_22.jpg.
# Saved Grad-CAM visualization for image 23 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_23.jpg.
# Saved Grad-CAM visualization for image 24 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_24.jpg.
# Saved Grad-CAM visualization for image 25 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_25.jpg.
# Saved Grad-CAM visualization for image 26 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_26.jpg.
# Saved Grad-CAM visualization for image 27 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_27.jpg.
# Saved Grad-CAM visualization for image 28 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_28.jpg.
# Saved Grad-CAM visualization for image 29 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_29.jpg.
# Saved Grad-CAM visualization for image 30 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_30.jpg.
# Saved Grad-CAM visualization for image 31 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_31.jpg.
# Saved Grad-CAM visualization for image 32 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_32.jpg.
# Saved Grad-CAM visualization for image 33 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_33.jpg.
# Saved Grad-CAM visualization for image 34 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_34.jpg.
# Saved Grad-CAM visualization for image 35 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_35.jpg.
# Saved Grad-CAM visualization for image 36 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_36.jpg.
# Saved Grad-CAM visualization for image 37 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_37.jpg.
# Saved Grad-CAM visualization for image 38 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_38.jpg.
# Saved Grad-CAM visualization for image 39 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_39.jpg.
# Saved Grad-CAM visualization for image 40 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_40.jpg.
# Saved Grad-CAM visualization for image 41 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_41.jpg.
# Saved Grad-CAM visualization for image 42 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_42.jpg.
# Saved Grad-CAM visualization for image 43 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_43.jpg.
# Saved Grad-CAM visualization for image 44 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_44.jpg.
# Saved Grad-CAM visualization for image 45 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_45.jpg.
# Saved Grad-CAM visualization for image 46 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_46.jpg.
# Saved Grad-CAM visualization for image 47 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_47.jpg.
# Saved Grad-CAM visualization for image 48 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_48.jpg.
# Saved Grad-CAM visualization for image 49 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_49.jpg.
# Saved Grad-CAM visualization for image 50 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_50.jpg.
# Saved Grad-CAM visualization for image 51 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_51.jpg.
# Saved Grad-CAM visualization for image 52 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_52.jpg.
# Saved Grad-CAM visualization for image 53 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_53.jpg.
# Saved Grad-CAM visualization for image 54 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_54.jpg.
# Saved Grad-CAM visualization for image 55 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_55.jpg.
# Saved Grad-CAM visualization for image 56 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_56.jpg.
# Saved Grad-CAM visualization for image 57 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_57.jpg.
# Saved Grad-CAM visualization for image 58 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_58.jpg.
# Saved Grad-CAM visualization for image 59 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_59.jpg.
# Saved Grad-CAM visualization for image 60 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_60.jpg.
# Saved Grad-CAM visualization for image 61 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_61.jpg.
# Saved Grad-CAM visualization for image 62 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_62.jpg.
# Saved Grad-CAM visualization for image 63 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_63.jpg.
# Saved Grad-CAM visualization for image 64 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_64.jpg.
# Saved Grad-CAM visualization for image 65 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_65.jpg.
# Saved Grad-CAM visualization for image 66 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_66.jpg.
# Saved Grad-CAM visualization for image 67 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_67.jpg.
# Saved Grad-CAM visualization for image 68 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_68.jpg.
# Saved Grad-CAM visualization for image 69 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_69.jpg.
# Saved Grad-CAM visualization for image 70 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_70.jpg.
# Saved Grad-CAM visualization for image 71 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_71.jpg.
# Saved Grad-CAM visualization for image 72 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_72.jpg.
# Saved Grad-CAM visualization for image 73 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_73.jpg.
# Saved Grad-CAM visualization for image 74 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_74.jpg.
# Saved Grad-CAM visualization for image 75 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_75.jpg.
# Saved Grad-CAM visualization for image 76 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_76.jpg.
# Saved Grad-CAM visualization for image 77 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_77.jpg.
# Saved Grad-CAM visualization for image 78 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_78.jpg.
# Saved Grad-CAM visualization for image 79 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_79.jpg.
# Saved Grad-CAM visualization for image 80 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_80.jpg.
# Saved Grad-CAM visualization for image 81 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_81.jpg.
# Saved Grad-CAM visualization for image 82 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_82.jpg.
# Saved Grad-CAM visualization for image 83 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_83.jpg.
# Saved Grad-CAM visualization for image 84 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_84.jpg.
# Saved Grad-CAM visualization for image 85 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_85.jpg.
# Saved Grad-CAM visualization for image 86 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_86.jpg.
# Saved Grad-CAM visualization for image 87 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_87.jpg.
# Saved Grad-CAM visualization for image 88 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_88.jpg.
# Saved Grad-CAM visualization for image 89 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_89.jpg.
# Saved Grad-CAM visualization for image 90 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_90.jpg.
# Saved Grad-CAM visualization for image 91 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_91.jpg.
# Saved Grad-CAM visualization for image 92 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_92.jpg.
# Saved Grad-CAM visualization for image 93 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_93.jpg.
# Saved Grad-CAM visualization for image 94 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_94.jpg.
# Saved Grad-CAM visualization for image 95 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_95.jpg.
# Saved Grad-CAM visualization for image 96 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_96.jpg.
# Saved Grad-CAM visualization for image 97 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_97.jpg.
# Saved Grad-CAM visualization for image 98 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_98.jpg.
# Saved Grad-CAM visualization for image 99 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_99.jpg.
# Saved Grad-CAM visualization for image 100 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_100.jpg.
# Saved Grad-CAM visualization for image 101 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_101.jpg.
# Saved Grad-CAM visualization for image 102 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_102.jpg.
# Saved Grad-CAM visualization for image 103 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_103.jpg.
# Saved Grad-CAM visualization for image 104 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_104.jpg.
# Saved Grad-CAM visualization for image 105 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_105.jpg.
# Saved Grad-CAM visualization for image 106 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_106.jpg.
# Saved Grad-CAM visualization for image 107 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_107.jpg.
# Saved Grad-CAM visualization for image 108 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_108.jpg.
# Saved Grad-CAM visualization for image 109 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_109.jpg.
# Saved Grad-CAM visualization for image 110 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_110.jpg.
# Saved Grad-CAM visualization for image 111 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_111.jpg.
# Saved Grad-CAM visualization for image 112 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_112.jpg.
# Saved Grad-CAM visualization for image 113 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_113.jpg.
# Saved Grad-CAM visualization for image 114 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_114.jpg.
# Saved Grad-CAM visualization for image 115 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_115.jpg.
# Saved Grad-CAM visualization for image 116 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_116.jpg.
# Saved Grad-CAM visualization for image 117 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_117.jpg.
# Saved Grad-CAM visualization for image 118 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_118.jpg.
# Saved Grad-CAM visualization for image 119 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_119.jpg.
# Saved Grad-CAM visualization for image 120 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_120.jpg.
# Saved Grad-CAM visualization for image 121 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_121.jpg.
# Saved Grad-CAM visualization for image 122 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_122.jpg.
# Saved Grad-CAM visualization for image 123 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_123.jpg.
# Saved Grad-CAM visualization for image 124 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_124.jpg.
# Saved Grad-CAM visualization for image 125 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_125.jpg.
# Saved Grad-CAM visualization for image 126 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_126.jpg.
# Saved Grad-CAM visualization for image 127 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_127.jpg.
# Saved Grad-CAM visualization for image 128 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_128.jpg.
# Saved Grad-CAM visualization for image 129 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_129.jpg.
# Saved Grad-CAM visualization for image 130 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_130.jpg.
# Saved Grad-CAM visualization for image 131 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_131.jpg.
# Saved Grad-CAM visualization for image 132 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_132.jpg.
# Saved Grad-CAM visualization for image 133 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_133.jpg.
# Saved Grad-CAM visualization for image 134 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_134.jpg.
# Saved Grad-CAM visualization for image 135 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_135.jpg.
# Saved Grad-CAM visualization for image 136 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_136.jpg.
# Saved Grad-CAM visualization for image 137 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_137.jpg.
# Saved Grad-CAM visualization for image 138 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_138.jpg.
# Saved Grad-CAM visualization for image 139 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_139.jpg.
# Saved Grad-CAM visualization for image 140 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_140.jpg.
# Saved Grad-CAM visualization for image 141 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_141.jpg.
# Saved Grad-CAM visualization for image 142 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_142.jpg.
# Saved Grad-CAM visualization for image 143 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_143.jpg.
# Saved Grad-CAM visualization for image 144 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_144.jpg.
# Saved Grad-CAM visualization for image 145 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_145.jpg.
# Saved Grad-CAM visualization for image 146 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_146.jpg.
# Saved Grad-CAM visualization for image 147 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_147.jpg.
# Saved Grad-CAM visualization for image 148 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_148.jpg.
# Saved Grad-CAM visualization for image 149 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_149.jpg.
# Saved Grad-CAM visualization for image 150 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_150.jpg.
# Saved Grad-CAM visualization for image 151 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_151.jpg.
# Saved Grad-CAM visualization for image 152 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_152.jpg.
# Saved Grad-CAM visualization for image 153 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_153.jpg.
# Saved Grad-CAM visualization for image 154 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_154.jpg.
# Saved Grad-CAM visualization for image 155 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_155.jpg.
# Saved Grad-CAM visualization for image 156 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_156.jpg.
# Saved Grad-CAM visualization for image 157 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_157.jpg.
# Saved Grad-CAM visualization for image 158 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_158.jpg.
# Saved Grad-CAM visualization for image 159 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_159.jpg.
# Saved Grad-CAM visualization for image 160 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_160.jpg.
# Saved Grad-CAM visualization for image 161 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_161.jpg.
# Saved Grad-CAM visualization for image 162 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_162.jpg.
# Saved Grad-CAM visualization for image 163 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_163.jpg.
# Saved Grad-CAM visualization for image 164 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_164.jpg.
# Saved Grad-CAM visualization for image 165 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_165.jpg.
# Saved Grad-CAM visualization for image 166 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_166.jpg.
# Saved Grad-CAM visualization for image 167 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_167.jpg.
# Saved Grad-CAM visualization for image 168 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_168.jpg.
# Saved Grad-CAM visualization for image 169 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_169.jpg.
# Saved Grad-CAM visualization for image 170 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_170.jpg.
# Saved Grad-CAM visualization for image 171 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_171.jpg.
# Saved Grad-CAM visualization for image 172 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_172.jpg.
# Saved Grad-CAM visualization for image 173 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_173.jpg.
# Saved Grad-CAM visualization for image 174 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_174.jpg.
# Saved Grad-CAM visualization for image 175 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_175.jpg.
# Saved Grad-CAM visualization for image 176 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_176.jpg.
# Saved Grad-CAM visualization for image 177 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_177.jpg.
# Saved Grad-CAM visualization for image 178 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_178.jpg.
# Saved Grad-CAM visualization for image 179 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_179.jpg.
# Saved Grad-CAM visualization for image 180 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_180.jpg.
# Saved Grad-CAM visualization for image 181 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_181.jpg.
# Saved Grad-CAM visualization for image 182 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_182.jpg.
# Saved Grad-CAM visualization for image 183 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_183.jpg.
# Saved Grad-CAM visualization for image 184 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_184.jpg.
# Saved Grad-CAM visualization for image 185 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_185.jpg.
# Saved Grad-CAM visualization for image 186 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_186.jpg.
# Saved Grad-CAM visualization for image 187 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_187.jpg.
# Saved Grad-CAM visualization for image 188 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_188.jpg.
# Saved Grad-CAM visualization for image 189 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_189.jpg.
# Saved Grad-CAM visualization for image 190 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_190.jpg.
# Saved Grad-CAM visualization for image 191 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_191.jpg.
# Saved Grad-CAM visualization for image 192 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_192.jpg.
# Saved Grad-CAM visualization for image 193 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_193.jpg.
# Saved Grad-CAM visualization for image 194 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_194.jpg.
# Saved Grad-CAM visualization for image 195 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_195.jpg.
# Saved Grad-CAM visualization for image 196 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_196.jpg.
# Saved Grad-CAM visualization for image 197 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_197.jpg.
# Saved Grad-CAM visualization for image 198 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_198.jpg.
# Saved Grad-CAM visualization for image 199 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_199.jpg.
# Saved Grad-CAM visualization for image 200 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_200.jpg.
# Saved Grad-CAM visualization for image 201 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_201.jpg.
# Saved Grad-CAM visualization for image 202 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_202.jpg.
# Saved Grad-CAM visualization for image 203 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_203.jpg.
# Saved Grad-CAM visualization for image 204 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_204.jpg.
# Saved Grad-CAM visualization for image 205 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_205.jpg.
# Saved Grad-CAM visualization for image 206 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_206.jpg.
# Saved Grad-CAM visualization for image 207 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_207.jpg.
# Saved Grad-CAM visualization for image 208 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_208.jpg.
# Saved Grad-CAM visualization for image 209 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_209.jpg.
# Saved Grad-CAM visualization for image 210 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_210.jpg.
# Saved Grad-CAM visualization for image 211 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_211.jpg.
# Saved Grad-CAM visualization for image 212 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_212.jpg.
# Saved Grad-CAM visualization for image 213 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_213.jpg.
# Saved Grad-CAM visualization for image 214 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_214.jpg.
# Saved Grad-CAM visualization for image 215 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_215.jpg.
# Saved Grad-CAM visualization for image 216 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_216.jpg.
# Saved Grad-CAM visualization for image 217 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_217.jpg.
# Saved Grad-CAM visualization for image 218 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_218.jpg.
# Saved Grad-CAM visualization for image 219 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_219.jpg.
# Saved Grad-CAM visualization for image 220 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_220.jpg.
# Saved Grad-CAM visualization for image 221 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_221.jpg.
# Saved Grad-CAM visualization for image 222 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_222.jpg.
# Saved Grad-CAM visualization for image 223 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_223.jpg.
# Saved Grad-CAM visualization for image 224 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_224.jpg.
# Saved Grad-CAM visualization for image 225 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_225.jpg.
# Saved Grad-CAM visualization for image 226 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_226.jpg.
# Saved Grad-CAM visualization for image 227 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_227.jpg.
# Saved Grad-CAM visualization for image 228 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_228.jpg.
# Saved Grad-CAM visualization for image 229 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_229.jpg.
# Saved Grad-CAM visualization for image 230 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_230.jpg.
# Saved Grad-CAM visualization for image 231 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_231.jpg.
# Saved Grad-CAM visualization for image 232 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_232.jpg.
# Saved Grad-CAM visualization for image 233 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_233.jpg.
# Saved Grad-CAM visualization for image 234 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_234.jpg.
# Saved Grad-CAM visualization for image 235 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_235.jpg.
# Saved Grad-CAM visualization for image 236 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_236.jpg.
# Saved Grad-CAM visualization for image 237 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_237.jpg.
# Saved Grad-CAM visualization for image 238 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_238.jpg.
# Saved Grad-CAM visualization for image 239 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_239.jpg.
# Saved Grad-CAM visualization for image 240 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_240.jpg.
# Saved Grad-CAM visualization for image 241 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_241.jpg.
# Saved Grad-CAM visualization for image 242 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_242.jpg.
# Saved Grad-CAM visualization for image 243 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_243.jpg.
# Saved Grad-CAM visualization for image 244 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_244.jpg.
# Saved Grad-CAM visualization for image 245 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_245.jpg.
# Saved Grad-CAM visualization for image 246 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_246.jpg.
# Saved Grad-CAM visualization for image 247 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_247.jpg.
# Saved Grad-CAM visualization for image 248 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_248.jpg.
# Saved Grad-CAM visualization for image 249 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_249.jpg.
# Saved Grad-CAM visualization for image 250 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_250.jpg.
# Saved Grad-CAM visualization for image 251 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_251.jpg.
# Saved Grad-CAM visualization for image 252 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_252.jpg.
# Saved Grad-CAM visualization for image 253 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_253.jpg.
# Saved Grad-CAM visualization for image 254 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_254.jpg.
# Saved Grad-CAM visualization for image 255 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_255.jpg.
# Saved Grad-CAM visualization for image 256 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_256.jpg.
# Saved Grad-CAM visualization for image 257 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_257.jpg.
# Saved Grad-CAM visualization for image 258 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_258.jpg.
# Saved Grad-CAM visualization for image 259 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_259.jpg.
# Saved Grad-CAM visualization for image 260 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_260.jpg.
# Saved Grad-CAM visualization for image 261 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_261.jpg.
# Saved Grad-CAM visualization for image 262 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_262.jpg.
# Saved Grad-CAM visualization for image 263 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_263.jpg.
# Saved Grad-CAM visualization for image 264 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_264.jpg.
# Saved Grad-CAM visualization for image 265 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_265.jpg.
# Saved Grad-CAM visualization for image 266 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_266.jpg.
# Saved Grad-CAM visualization for image 267 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_267.jpg.
# Saved Grad-CAM visualization for image 268 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_268.jpg.
# Saved Grad-CAM visualization for image 269 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_269.jpg.
# Saved Grad-CAM visualization for image 270 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_270.jpg.
# Saved Grad-CAM visualization for image 271 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_271.jpg.
# Saved Grad-CAM visualization for image 272 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_272.jpg.
# Saved Grad-CAM visualization for image 273 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_273.jpg.
# Saved Grad-CAM visualization for image 274 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_274.jpg.
# Saved Grad-CAM visualization for image 275 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_275.jpg.
# Saved Grad-CAM visualization for image 276 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_276.jpg.
# Saved Grad-CAM visualization for image 277 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_277.jpg.
# Saved Grad-CAM visualization for image 278 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_278.jpg.
# Saved Grad-CAM visualization for image 279 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_279.jpg.
# Saved Grad-CAM visualization for image 280 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_280.jpg.
# Saved Grad-CAM visualization for image 281 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_281.jpg.
# Saved Grad-CAM visualization for image 282 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_282.jpg.
# Saved Grad-CAM visualization for image 283 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_283.jpg.
# Saved Grad-CAM visualization for image 284 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_284.jpg.
# Saved Grad-CAM visualization for image 285 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_285.jpg.
# Saved Grad-CAM visualization for image 286 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_286.jpg.
# Saved Grad-CAM visualization for image 287 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_287.jpg.
# Saved Grad-CAM visualization for image 288 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_288.jpg.
# Saved Grad-CAM visualization for image 289 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_289.jpg.
# Saved Grad-CAM visualization for image 290 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_290.jpg.
# Saved Grad-CAM visualization for image 291 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_291.jpg.
# Saved Grad-CAM visualization for image 292 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_292.jpg.
# Saved Grad-CAM visualization for image 293 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_293.jpg.
# Saved Grad-CAM visualization for image 294 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_294.jpg.
# Saved Grad-CAM visualization for image 295 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_295.jpg.
# Saved Grad-CAM visualization for image 296 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_296.jpg.
# Saved Grad-CAM visualization for image 297 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_297.jpg.
# Saved Grad-CAM visualization for image 298 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_298.jpg.
# Saved Grad-CAM visualization for image 299 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_299.jpg.
# Saved Grad-CAM visualization for image 300 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_300.jpg.
# Saved Grad-CAM visualization for image 301 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_301.jpg.
# Saved Grad-CAM visualization for image 302 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_302.jpg.
# Saved Grad-CAM visualization for image 303 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_303.jpg.
# Saved Grad-CAM visualization for image 304 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_304.jpg.
# Saved Grad-CAM visualization for image 305 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_305.jpg.
# Saved Grad-CAM visualization for image 306 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_306.jpg.
# Saved Grad-CAM visualization for image 307 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_307.jpg.
# Saved Grad-CAM visualization for image 308 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_308.jpg.
# Saved Grad-CAM visualization for image 309 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_309.jpg.
# Saved Grad-CAM visualization for image 310 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_310.jpg.
# Saved Grad-CAM visualization for image 311 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_311.jpg.
# Saved Grad-CAM visualization for image 312 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_312.jpg.
# Saved Grad-CAM visualization for image 313 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_313.jpg.
# Saved Grad-CAM visualization for image 314 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_314.jpg.
# Saved Grad-CAM visualization for image 315 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_315.jpg.
# Saved Grad-CAM visualization for image 316 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_316.jpg.
# Saved Grad-CAM visualization for image 317 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_317.jpg.
# Saved Grad-CAM visualization for image 318 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_318.jpg.
# Saved Grad-CAM visualization for image 319 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_319.jpg.
# Saved Grad-CAM visualization for image 320 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_320.jpg.
# Saved Grad-CAM visualization for image 321 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_321.jpg.
# Saved Grad-CAM visualization for image 322 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_322.jpg.
# Saved Grad-CAM visualization for image 323 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_323.jpg.
# Saved Grad-CAM visualization for image 324 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_324.jpg.
# Saved Grad-CAM visualization for image 325 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_325.jpg.
# Saved Grad-CAM visualization for image 326 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_326.jpg.
# Saved Grad-CAM visualization for image 327 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_327.jpg.
# Saved Grad-CAM visualization for image 328 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_328.jpg.
# Saved Grad-CAM visualization for image 329 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_329.jpg.
# Saved Grad-CAM visualization for image 330 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_330.jpg.
# Saved Grad-CAM visualization for image 331 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_331.jpg.
# Saved Grad-CAM visualization for image 332 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_332.jpg.
# Saved Grad-CAM visualization for image 333 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_333.jpg.
# Saved Grad-CAM visualization for image 334 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_334.jpg.
# Saved Grad-CAM visualization for image 335 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_335.jpg.
# Saved Grad-CAM visualization for image 336 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_336.jpg.
# Saved Grad-CAM visualization for image 337 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_337.jpg.
# Saved Grad-CAM visualization for image 338 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_338.jpg.
# Saved Grad-CAM visualization for image 339 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_339.jpg.
# Saved Grad-CAM visualization for image 340 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_340.jpg.
# Saved Grad-CAM visualization for image 341 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_341.jpg.
# Saved Grad-CAM visualization for image 342 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_342.jpg.
# Saved Grad-CAM visualization for image 343 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_343.jpg.
# Saved Grad-CAM visualization for image 344 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_344.jpg.
# Saved Grad-CAM visualization for image 345 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_345.jpg.
# Saved Grad-CAM visualization for image 346 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_346.jpg.
# Saved Grad-CAM visualization for image 347 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_347.jpg.
# Saved Grad-CAM visualization for image 348 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_348.jpg.
# Saved Grad-CAM visualization for image 349 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_349.jpg.
# Saved Grad-CAM visualization for image 350 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_350.jpg.
# Saved Grad-CAM visualization for image 351 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_351.jpg.
# Saved Grad-CAM visualization for image 352 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_352.jpg.
# Saved Grad-CAM visualization for image 353 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_353.jpg.
# Saved Grad-CAM visualization for image 354 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_354.jpg.
# Saved Grad-CAM visualization for image 355 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_355.jpg.
# Saved Grad-CAM visualization for image 356 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_356.jpg.
# Saved Grad-CAM visualization for image 357 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_357.jpg.
# Saved Grad-CAM visualization for image 358 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_358.jpg.
# Saved Grad-CAM visualization for image 359 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_359.jpg.
# Saved Grad-CAM visualization for image 360 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_360.jpg.
# Saved Grad-CAM visualization for image 361 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_361.jpg.
# Saved Grad-CAM visualization for image 362 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_362.jpg.
# Saved Grad-CAM visualization for image 363 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_363.jpg.
# Saved Grad-CAM visualization for image 364 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_364.jpg.
# Saved Grad-CAM visualization for image 365 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_365.jpg.
# Saved Grad-CAM visualization for image 366 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_366.jpg.
# Saved Grad-CAM visualization for image 367 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_367.jpg.
# Saved Grad-CAM visualization for image 368 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_368.jpg.
# ...
# Saved Grad-CAM visualization for image 391 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_391.jpg.
# Saved Grad-CAM visualization for image 392 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_392.jpg.
# Saved Grad-CAM visualization for image 393 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_393.jpg.
# Saved Grad-CAM visualization for image 394 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_394.jpg.
# Saved Grad-CAM visualization for image 395 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_395.jpg.
# Saved Grad-CAM visualization for image 396 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_396.jpg.
# Saved Grad-CAM visualization for image 397 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_397.jpg.
# Saved Grad-CAM visualization for image 398 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_398.jpg.
# Saved Grad-CAM visualization for image 399 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_399.jpg.
# Saved Grad-CAM visualization for image 400 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_400.jpg.
# Saved Grad-CAM visualization for image 401 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_401.jpg.
# Saved Grad-CAM visualization for image 402 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_402.jpg.
# Saved Grad-CAM visualization for image 403 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_403.jpg.
# Saved Grad-CAM visualization for image 404 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_404.jpg.
# Saved Grad-CAM visualization for image 405 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_405.jpg.
# Saved Grad-CAM visualization for image 406 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_406.jpg.
# Saved Grad-CAM visualization for image 407 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_407.jpg.
# Saved Grad-CAM visualization for image 408 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_408.jpg.
# Saved Grad-CAM visualization for image 409 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_409.jpg.
# Saved Grad-CAM visualization for image 410 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_410.jpg.
# Saved Grad-CAM visualization for image 411 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_411.jpg.
# Saved Grad-CAM visualization for image 412 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_412.jpg.
# Saved Grad-CAM visualization for image 413 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_413.jpg.
# Saved Grad-CAM visualization for image 414 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_414.jpg.
# Saved Grad-CAM visualization for image 415 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_415.jpg.
# Saved Grad-CAM visualization for image 416 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_416.jpg.
# Saved Grad-CAM visualization for image 417 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_417.jpg.
# Saved Grad-CAM visualization for image 418 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_418.jpg.
# Saved Grad-CAM visualization for image 419 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_419.jpg.
# Saved Grad-CAM visualization for image 420 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_420.jpg.
# Saved Grad-CAM visualization for image 421 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_421.jpg.
# Saved Grad-CAM visualization for image 422 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_422.jpg.
# Saved Grad-CAM visualization for image 423 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_423.jpg.
# Saved Grad-CAM visualization for image 424 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_424.jpg.
# Saved Grad-CAM visualization for image 425 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_425.jpg.
# Saved Grad-CAM visualization for image 426 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_426.jpg.
# Saved Grad-CAM visualization for image 427 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_427.jpg.
# Saved Grad-CAM visualization for image 428 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_428.jpg.
# Saved Grad-CAM visualization for image 429 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_429.jpg.
# Saved Grad-CAM visualization for image 430 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_430.jpg.
# Saved Grad-CAM visualization for image 431 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_431.jpg.
# Saved Grad-CAM visualization for image 432 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_432.jpg.
# Saved Grad-CAM visualization for image 433 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_433.jpg.
# Saved Grad-CAM visualization for image 434 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_434.jpg.
# Saved Grad-CAM visualization for image 435 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_435.jpg.
# Saved Grad-CAM visualization for image 436 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_436.jpg.
# Saved Grad-CAM visualization for image 437 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_437.jpg.
# Saved Grad-CAM visualization for image 438 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_438.jpg.
# Saved Grad-CAM visualization for image 439 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_439.jpg.
# Saved Grad-CAM visualization for image 440 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_440.jpg.
# Saved Grad-CAM visualization for image 441 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_441.jpg.
# Saved Grad-CAM visualization for image 442 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_442.jpg.
# Saved Grad-CAM visualization for image 443 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_443.jpg.
# Saved Grad-CAM visualization for image 444 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_444.jpg.
# Saved Grad-CAM visualization for image 445 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_445.jpg.
# Saved Grad-CAM visualization for image 446 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_446.jpg.
# Saved Grad-CAM visualization for image 447 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_447.jpg.
# Saved Grad-CAM visualization for image 448 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_448.jpg.
# Saved Grad-CAM visualization for image 449 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_449.jpg.
# Saved Grad-CAM visualization for image 450 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_450.jpg.
# Saved Grad-CAM visualization for image 451 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_451.jpg.
# Saved Grad-CAM visualization for image 452 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_452.jpg.
# Saved Grad-CAM visualization for image 453 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_453.jpg.
# Saved Grad-CAM visualization for image 454 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_454.jpg.
# Saved Grad-CAM visualization for image 455 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_455.jpg.
# Saved Grad-CAM visualization for image 456 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_456.jpg.
# Saved Grad-CAM visualization for image 457 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_457.jpg.
# Saved Grad-CAM visualization for image 458 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_458.jpg.
# Saved Grad-CAM visualization for image 459 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_459.jpg.
# Saved Grad-CAM visualization for image 460 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_460.jpg.
# Saved Grad-CAM visualization for image 461 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_461.jpg.
# Saved Grad-CAM visualization for image 462 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_462.jpg.
# Saved Grad-CAM visualization for image 463 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_463.jpg.
# Saved Grad-CAM visualization for image 464 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_464.jpg.
# Saved Grad-CAM visualization for image 465 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_465.jpg.
# Saved Grad-CAM visualization for image 466 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_466.jpg.
# Saved Grad-CAM visualization for image 467 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_467.jpg.
# Saved Grad-CAM visualization for image 468 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_468.jpg.
# Saved Grad-CAM visualization for image 469 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_469.jpg.
# Saved Grad-CAM visualization for image 470 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_470.jpg.
# Saved Grad-CAM visualization for image 471 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_471.jpg.
# Saved Grad-CAM visualization for image 472 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_472.jpg.
# Saved Grad-CAM visualization for image 473 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_473.jpg.
# Saved Grad-CAM visualization for image 474 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_474.jpg.
# Saved Grad-CAM visualization for image 475 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_475.jpg.
# Saved Grad-CAM visualization for image 476 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_476.jpg.
# Saved Grad-CAM visualization for image 477 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_477.jpg.
# Saved Grad-CAM visualization for image 478 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_478.jpg.
# Saved Grad-CAM visualization for image 479 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_479.jpg.
# Saved Grad-CAM visualization for image 480 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_480.jpg.
# Saved Grad-CAM visualization for image 481 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_481.jpg.
# Saved Grad-CAM visualization for image 482 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_482.jpg.
# Saved Grad-CAM visualization for image 483 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_483.jpg.
# Saved Grad-CAM visualization for image 484 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_484.jpg.
# Saved Grad-CAM visualization for image 485 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_485.jpg.
# Saved Grad-CAM visualization for image 486 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_486.jpg.
# Saved Grad-CAM visualization for image 487 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_487.jpg.
# Saved Grad-CAM visualization for image 488 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_488.jpg.
# Saved Grad-CAM visualization for image 489 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_489.jpg.
# Saved Grad-CAM visualization for image 490 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_490.jpg.
# Saved Grad-CAM visualization for image 491 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_491.jpg.
# Saved Grad-CAM visualization for image 492 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_492.jpg.
# Saved Grad-CAM visualization for image 493 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_493.jpg.
# Saved Grad-CAM visualization for image 494 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_494.jpg.
# Saved Grad-CAM visualization for image 495 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_495.jpg.
# Saved Grad-CAM visualization for image 496 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_496.jpg.
# Saved Grad-CAM visualization for image 497 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_497.jpg.
# Saved Grad-CAM visualization for image 498 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_498.jpg.
# Saved Grad-CAM visualization for image 499 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_499.jpg.
# Saved Grad-CAM visualization for image 500 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_500.jpg.
# Saved Grad-CAM visualization for image 501 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_501.jpg.
# Saved Grad-CAM visualization for image 502 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_502.jpg.
# Saved Grad-CAM visualization for image 503 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_503.jpg.
# Saved Grad-CAM visualization for image 504 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_504.jpg.
# Saved Grad-CAM visualization for image 505 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_505.jpg.
# Saved Grad-CAM visualization for image 506 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_506.jpg.
# Saved Grad-CAM visualization for image 507 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_507.jpg.
# Saved Grad-CAM visualization for image 508 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_508.jpg.
# Saved Grad-CAM visualization for image 509 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_509.jpg.
# Saved Grad-CAM visualization for image 510 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_510.jpg.
# Saved Grad-CAM visualization for image 511 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_511.jpg.
# Saved Grad-CAM visualization for image 512 at C:\Users\jamee\Favorites\Downloads\GradCam\grad_cam_visualizations\grad_cam_512.jpg.

# %%
# for class_index in range(24):  # Loop through all 24 classes (0 to 23)
#     for i, (image_tensor, img_path) in enumerate(test_loader):
#         image_tensor = image_tensor.to(device)
#         img_path = img_path[0]  # Extract single image path

#         # Generate Grad-CAM heatmap for the current class
#         targets = [ClassifierOutputTarget(class_index)]  
#         grayscale_cam = cam(input_tensor=image_tensor, targets=targets)[0]  # [0] for single image

#         # Normalize the grayscale CAM to remove noise
#         grayscale_cam = (grayscale_cam - grayscale_cam.min()) / (grayscale_cam.max() - grayscale_cam.min())

#         # Load the original image for visualization
#         original_image = cv2.imread(img_path)
#         original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
#         original_image = cv2.resize(original_image, (224, 224))
#         original_image = np.float32(original_image) / 255.0

#         # Overlay Grad-CAM heatmap on the original image
#         heatmap = show_cam_on_image(original_image, grayscale_cam, use_rgb=True)

#         # Convert both images to BGR format for OpenCV display
#         original_image_bgr = (original_image * 255).astype(np.uint8)
#         heatmap_bgr = (heatmap * 255).astype(np.uint8)

#         # Combine the original image and Grad-CAM heatmap side by side
#         combined_image = cv2.hconcat([original_image_bgr, heatmap_bgr])

#         # Save the combined image
#         output_path = os.path.join(output_dir, f"class_{class_index}_grad_cam_{i + 1}.jpg")
#         cv2.imwrite(output_path, combined_image)
#         print(f"Saved combined Grad-CAM visualization for image {i + 1} with class index {class_index} at {output_path}.")
